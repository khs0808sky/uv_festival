# %%
# -*- coding: utf-8 -*-
"""
🎯 (2024+2025) 축제명 + 기준 월 → 같은 '분기'에 열리는 축제만 리스트업 (유사시기 단일 필터)
- 분기 규칙: 1→[1,2,3], 4/5/6→[4,5,6], 7/8/9→[7,8,9], 10/11/12→[10,11,12]
- 로드: ./csv/{2024,2025}_축제_핵심필드.csv (+ /mnt/data 경로도 시도)
- 아직 시작 안 한 축제(시작일 > 오늘) 제외
- 입력 축제명(정확·유사) 제외
- 출력: 기본 "축제명  (표시월)" / show_period=True면 "축제명  시작일~종료일  (표시월)"
"""

import os, re
from pathlib import Path
from typing import Optional, List, Dict, Set

import pandas as pd
from difflib import get_close_matches

# ---------------- Settings --------------------
CANDIDATE_FILES = [
    "./csv/2024_축제_핵심필드.csv",
    "./csv/2025_축제_핵심필드.csv",
    "/mnt/data/2024_축제_핵심필드.csv",
    "/mnt/data/2025_축제_핵심필드.csv",
]

# ---------------- Utils -----------------------
def normalize_text(s: str) -> str:
    if s is None: return ""
    s = str(s).strip().replace("\xa0", " ")
    return re.sub(r"\s+", "", s)

def parse_date_str(s: str) -> Optional[pd.Timestamp]:
    try:
        return pd.to_datetime(str(s), format="%Y-%m-%d", errors="coerce")
    except Exception:
        return None

def today_floor_ts() -> pd.Timestamp:
    return pd.Timestamp.today().normalize()

def standardize_columns(df: pd.DataFrame) -> pd.DataFrame:
    """'축제유형' -> '축제 유형' 등 표준화 (본 스크립트는 유형 미사용이지만 컬럼 검증용)."""
    colmap = {}
    for c in df.columns:
        cc = str(c).strip()
        if cc == "축제유형":
            colmap[c] = "축제 유형"
    return df.rename(columns=colmap)

def ensure_columns(df: pd.DataFrame) -> pd.DataFrame:
    df = standardize_columns(df)
    needed = ["연번", "광역자치단체명", "기초자치단체명", "축제명", "시작일", "종료일"]
    for c in needed:
        if c not in df.columns:
            raise ValueError(f"필수 컬럼 누락: {c}")
    return df

def read_many_csv(paths: List[str]) -> pd.DataFrame:
    frames = []
    for p in paths:
        if Path(p).exists():
            try:
                df = pd.read_csv(p, dtype=str).fillna("")
            except UnicodeDecodeError:
                df = pd.read_csv(p, dtype=str, encoding="utf-8-sig").fillna("")
            df = ensure_columns(df)
            df["_출처파일"] = Path(p).name
            frames.append(df)
    if not frames:
        raise FileNotFoundError("입력 CSV를 하나도 찾지 못했습니다.")
    out = pd.concat(frames, ignore_index=True)
    out = out.drop_duplicates(
        subset=["광역자치단체명","기초자치단체명","축제명","시작일","종료일"],
        keep="first"
    ).reset_index(drop=True)
    return out

def months_in_range(start: Optional[pd.Timestamp], end: Optional[pd.Timestamp]) -> Set[int]:
    """시작~종료 사이의 월(1..12) 집합. 연도 넘어가도 월만 모음."""
    if (start is None or pd.isna(start)) or (end is None or pd.isna(end)):
        return set()
    if end < start:
        start, end = end, start
    months = set()
    cur = pd.Timestamp(year=start.year, month=start.month, day=1)
    last = pd.Timestamp(year=end.year, month=end.month, day=1)
    while cur <= last:
        months.add(int(cur.month))
        if cur.month == 12:
            cur = pd.Timestamp(year=cur.year + 1, month=1, day=1)
        else:
            cur = pd.Timestamp(year=cur.year, month=cur.month + 1, day=1)
    return months

def quarter_months(pivot_month: int) -> List[int]:
    """1→[1,2,3], 4/5/6→[4,5,6], 7/8/9→[7,8,9], 10/11/12→[10,11,12]"""
    m = int(pivot_month)
    if m in (1,2,3):  return [1,2,3]
    if m in (4,5,6):  return [4,5,6]
    if m in (7,8,9):  return [7,8,9]
    return [10,11,12]

def circular_month_distance(a: int, b: int) -> int:
    a, b = int(a), int(b)
    d = abs(a - b)
    return min(d, 12 - d)

# ---------------- Core ------------------------
def load_data(csv_path_override: Optional[str] = None) -> pd.DataFrame:
    if csv_path_override and Path(csv_path_override).exists():
        try:
            df = pd.read_csv(csv_path_override, dtype=str).fillna("")
        except UnicodeDecodeError:
            df = pd.read_csv(csv_path_override, dtype=str, encoding="utf-8-sig").fillna("")
        df = ensure_columns(df)
        df["_출처파일"] = Path(csv_path_override).name
        return df
    return read_many_csv(CANDIDATE_FILES)

def filter_by_quarter_time_only(
    df: pd.DataFrame,
    query_name: str,
    pivot_month: int,
) -> pd.DataFrame:
    """유사 시기(분기)만으로 필터링."""
    qmonths = set(quarter_months(pivot_month)).copy()

    # 날짜 파싱 + 아직 시작 안 한 축제 제외
    today = today_floor_ts()
    df = df.copy()
    df["시작일_dt"] = df["시작일"].apply(parse_date_str)
    df["종료일_dt"] = df["종료일"].apply(parse_date_str)
    df = df[(~df["시작일_dt"].isna()) & (~df["종료일_dt"].isna()) & (df["시작일_dt"] <= today)]

    # 입력 축제명(정확·유사) 제외
    inorm = normalize_text(query_name)
    all_names = df["축제명"].astype(str).tolist()
    close = set(get_close_matches(query_name, all_names, n=3, cutoff=0.85))
    def _is_self(x: str) -> bool:
        nx = normalize_text(x)
        return (nx == inorm) or (x in close)
    df = df[~df["축제명"].astype(str).apply(_is_self)]

    # 분기와 겹치는 것만
    def _keep(row) -> bool:
        rng = months_in_range(row["시작일_dt"], row["종료일_dt"])
        return len(rng & qmonths) > 0
    df = df[df.apply(_keep, axis=1)].copy()

    # 표시월 계산: 분기 내 겹치는 월 중 pivot에 가장 가까운 월
    df["시작월"] = df["시작일_dt"].dt.month.astype(int)
    def _display_month(row) -> int:
        rng = months_in_range(row["시작일_dt"], row["종료일_dt"]) & qmonths
        if not rng:
            return int(row["시작월"])
        if pivot_month in rng:
            return int(pivot_month)
        return sorted(list(rng), key=lambda m: circular_month_distance(m, pivot_month))[0]
    df["표시월"] = df.apply(_display_month, axis=1).astype(int)

    # 정렬 & 정리
    df["_sd"] = df["시작일_dt"]
    df = df.sort_values(by=["표시월","_sd","축제명"]).drop(columns=["_sd"]).reset_index(drop=True)
    return df[["광역자치단체명","기초자치단체명","축제명","시작일","종료일","표시월","_출처파일"]]

# ---------------- Runner -----------------------
def run_timeonly_quarter(
    festival_name: str,
    pivot_month: int,
    csv_path_override: Optional[str] = None,
    print_limit: int = 300,
    dedupe: bool = True,
    show_period: bool = False,  # True면 "이름  시작~종료 (표시월)"
):
    df = load_data(csv_path_override)
    out = filter_by_quarter_time_only(df, festival_name, int(pivot_month))

    # 중복 이름 제거(원하면)
    if dedupe and not out.empty:
        out = out.drop_duplicates(subset=["축제명"], keep="first")

    # 출력
    print(f"입력 축제명: {festival_name} | 기준 월: {pivot_month} → 분기월={quarter_months(pivot_month)}")
    rows = []
    for _, r in out.iterrows():
        if show_period:
            rows.append(f"{r['축제명']}  {r['시작일']}~{r['종료일']}  ({int(r['표시월'])}월)")
        else:
            rows.append(f"{r['축제명']}  ({int(r['표시월'])}월)")

    print(f"\n같은 분기(유사시기) 축제 수: {len(rows)}")
    if rows:
        print("\n[목록]")
        for i, line in enumerate(rows[:print_limit], start=1):
            print(f"{i:>3}. {line}")
        if len(rows) > print_limit:
            print(f"... ({len(rows)-print_limit}개 더 있음)")
    return out

# ------------- Example -------------
if __name__ == "__main__":
    # 예: '담양산타축제', 12월 기준 → 10~12월 유사시기만
    run_timeonly_quarter("홍어축제", pivot_month=4, show_period=True)
    # run_timeonly_quarter("임실 산타축제", pivot_month=1, show_period=False)
# Out:
# 입력 축제명: 홍어축제 | 기준 월: 4 → 분기월=[4, 5, 6]
#
# 같은 분기(유사시기) 축제 수: 468
#
# [목록]
#   1. 제62회 진해군항제
# (군악의장페스티벌)  2024-03-23~2024-04-01  (4월)
#   2. 2024 경포 벚꽃 축제  2024-03-29~2024-04-03  (4월)
#   3. 2024년 섬수선화축제  2024-03-29~2024-04-07  (4월)
#   4. 정읍 벚꽃축제  2024-03-29~2024-04-01  (4월)
#   5. 청춘, 금오천 벚꽃 페스티벌  2024-03-30~2024-04-02  (4월)
#   6. 강남동 새봄맞이 축제  2024-03-31~2024-04-02  (4월)
#   7. 제2회 십승지명당운본고원벚꽃축제  2024-04-01~2024-04-01  (4월)
#   8. 금성면 제1회 고비산 산벚꽃축제  2024-04-02~2024-04-02  (4월)
#   9. 안양충훈벚꽃축제  2024-04-02~2024-04-02  (4월)
#  10. 제28회 비슬산 참꽃 문화제  2024-04-02~2024-04-02  (4월)
#  11. 제2회 남대천 벚꽃축제  2024-04-02~2024-04-02  (4월)
#  12. 우이천 벚꽃 축제  2024-04-03~2024-04-07  (4월)
#  13. 2024 보은 벚꽃길 축제  2024-04-05~2024-04-07  (4월)
#  14. 2024 섬 튤립축제  2024-04-05~2024-04-14  (4월)
#  15. 제8회여주흥천남한강벚꽃축제  2024-04-05~2024-04-07  (4월)
#  16. 2024 영랑호 벚꽃축제  2024-04-06~2024-04-07  (4월)
#  17. 2024년 인천대공원 벚꽃축제  2024-04-06~2024-04-07  (4월)
#  18. 제20회삼척맹방유채꽃축제  2024-04-06~2024-04-14  (4월)
#  19. 제19회 창녕낙동강유채축제  2024-04-11~2024-04-14  (4월)
#  20. 419혁명국민문화제  2024-04-12~2024-04-19  (4월)
#  21. 동해항 크랩킹페스타  2024-04-12~2024-04-14  (4월)
#  22. 제12회 장봉도 벚꽃축제  2024-04-13~2024-04-13  (4월)
#  23. 제2회 전국 새우란 축제  2024-04-16~2024-04-21  (4월)
#  24. 제49회 의령 홍의장군축제  2024-04-18~2024-04-21  (4월)
#  25. 2024 사천시 삼천포항
# 수산물축제  2024-04-19~2024-04-21  (4월)
#  26. 2024 익산 문화유산야행  2024-04-19~2024-04-21  (4월)
#  27. 2024 화순 고인돌 축제  2024-04-19~2024-04-28  (4월)
#  28. 2024년 가야문화축제  2024-04-19~2024-04-23  (4월)
#  29. 2024년 밀양 문화유산 야행  2024-04-19~2024-04-21  (4월)
#  30. 제21회 청도소싸움축제  2024-04-19~2024-04-21  (4월)
#  31. 제4회 강진 성전월출산 봄소풍가는날  2024-04-19~2024-04-21  (4월)
#  32. 제80회 지리산남악제 및 43회 군민의 날 행사  2024-04-19~2024-04-21  (4월)
#  33. 고창 청보리밭축제  2024-04-20~2024-05-12  (4월)
#  34. 군포철쭉축제  2024-04-20~2024-04-28  (4월)
#  35. 선농대제  2024-04-20~2024-04-20  (4월)
#  36. 지평선광활햇감자축제  2024-04-20~2024-04-21  (4월)
#  37. 평택 꽃 나들이  2024-04-20~2024-04-24  (4월)
#  38. 2024 광주 문화유산 야행 '돌의 기억'  2024-04-26~2024-04-27  (4월)
#  39. 2024 대한민국 과학축제  2024-04-26~2024-04-28  (4월)
#  40. 2024고양국제꽃박람회  2024-04-26~2024-05-12  (4월)
#  41. 거제맹종대나무 축제  2024-04-26~2024-04-28  (4월)
#  42. 단종문화제  2024-04-26~2024-04-28  (4월)
#  43. 제13회 우도소라축제  2024-04-26~2024-04-28  (4월)
#  44. 제14회 용문산 산나물 축제  2024-04-26~2024-04-28  (4월)
#  45. 제17회 김제모락페스티벌  2024-04-26~2024-04-27  (4월)
#  46. 제26회 사천와룡문화제  2024-04-26~2024-04-28  (4월)
#  47. 제26회 함평나비대축제  2024-04-26~2024-05-05  (4월)
#  48. 제5회 대한민국 & 제30회 함안수박축제  2024-04-26~2024-04-28  (4월)
#  49. 제6회 창선고사리축제  2024-04-26~2024-04-27  (4월)
#  50. 태백 천상의 산나물축제  2024-04-26~2024-04-28  (4월)
#  51. 흑석산 소풍 힐링축제  2024-04-26~2024-04-27  (4월)
#  52. 가산산성 문화유산 야행  2024-04-27~2024-04-28  (4월)
#  53. 제26회 문경찻사발축제  2024-04-27~2024-05-06  (4월)
#  54. 제27회 동춘당문화제  2024-04-27~2024-04-27  (4월)
#  55. 포항해병대문화축제  2024-04-27~2024-04-28  (4월)
#  56. 2024 섬 겨울꽃 축제  2024-12-06~2024-01-01  (4월)
#  57. 상주 해돋이&물메기 축제  2024-12-31~2024-01-01  (4월)
#  58. 왜목마을해넘이해돋이소원제  2024-12-31~2024-01-01  (4월)
#  59. 포항 구룡포 과메기&겨울바다 축제  2024-12-31~2024-01-01  (4월)
#  60. 호미곶한민족해맞이축전  2024-12-31~2024-01-01  (4월)
#  61. 홍성 남당항 새조개와 함께하는 수산물축제  2025-02-07~2025-04-07  (4월)
#  62. 무창포 주꾸미 도다리 축제  2025-03-22~2025-04-13  (4월)
#  63. 제21회 삼척맹방유채꽃축제  2025-03-27~2025-04-20  (4월)
#  64. 2025 대덕물빛축제  2025-03-28~2025-04-26  (4월)
#  65. 2025년 섬 수선화축제  2025-03-28~2025-04-06  (4월)
#  66. 경포 벚꽃 축제  2025-03-28~2025-04-02  (4월)
#  67. 도봉 벚꽃축제  2025-03-28~2025-04-03  (4월)
#  68. 2025 연화지 벚꽃 페스타  2025-03-29~2025-04-06  (4월)
#  69. 부천 페스타(B-festa)-봄꽃여행  2025-03-29~2025-04-06  (4월)
#  70. 서대문봄빛축제  2025-03-29~2025-04-06  (4월)
#  71. 제26회 영암왕인문화축제  2025-03-29~2025-04-06  (4월)
#  72. 제45회 진도신비의바닷길축제  2025-03-29~2025-04-01  (4월)
#  73. 제63회 진해군항제  2025-03-29~2025-04-06  (4월)
#  74. 제6회 울주작천정벚꽃축제  2025-03-29~2025-04-06  (4월)
#  75. 제7회 대청호 벚꽃축제(가칭)  2025-03-29~2025-04-06  (4월)
#  76. 제12회 보성벚꽃축제  2025-03-31~2025-04-01  (4월)
#  77. 우산지락  2025-04-01~2025-10-31  (4월)
#  78. 송파구 벚꽃축제  2025-04-02~2025-04-06  (4월)
#  79. 2025 벚꽃축제  2025-04-03~2025-04-07  (4월)
#  80. 2025 꽃빛드리축제  2025-04-04~2025-04-06  (4월)
#  81. 2025 만석거 새빛 축제  2025-04-04~2025-04-13  (4월)
#  82. 2025 보은벚꽃길축제  2025-04-04~2025-04-13  (4월)
#  83. 2025 섬 튤립축제  2025-04-04~2025-04-13  (4월)
#  84. 2025 양양 생태생명축제  2025-04-04~2025-04-13  (4월)
#  85. 제10회 사천비토섬별주부전축제  2025-04-04~2025-04-05  (4월)
#  86. 제12회 전천축제  2025-04-04~2025-04-06  (4월)
#  87. 제1회 면천의 봄  2025-04-04~2025-04-06  (4월)
#  88. 제3회 고창 벚꽃축제  2025-04-04~2025-04-06  (4월)
#  89. 제8회 갈산누리봄축제  2025-04-04~2025-04-06  (4월)
#  90. 제9회여주흥천남한강벚꽃축제  2025-04-04~2025-04-06  (4월)
#  91. 2025 안양충훈벚꽃축제  2025-04-05~2025-04-06  (4월)
#  92. 2025 유달산 봄축제  2025-04-05~2025-04-06  (4월)
#  93. 2025 청산도슬로걷기축제  2025-04-05~2025-05-04  (4월)
#  94. 2025년 인천대공원 벚꽃축제  2025-04-05~2025-04-06  (4월)
#  95. 2025년 조치원 봄꽃축제  2025-04-05~2025-04-06  (4월)
#  96. 고려산 진달래꽃구경  2025-04-05~2025-04-13  (4월)
#  97. 김포 벚꽃축제  2025-04-05~2025-04-06  (4월)
#  98. 동대문구 봄꽃축제  2025-04-05~2025-04-06  (4월)
#  99. 제11회 이천체험문화축제  2025-04-05~2025-04-06  (4월)
# 100. 제1회 숭어축제  2025-04-05~2025-04-06  (4월)
# 101. 제1회 슬도 봄꽃 축제  2025-04-05~2025-04-06  (4월)
# 102. 제25회 농다리 축제  2025-04-05~2025-06-01  (4월)
# 103. 제3회 남대천 벚꽃축제  2025-04-05~2025-04-06  (4월)
# 104. 제3회 완주 모악산 웰니스축제  2025-04-05~2025-04-06  (4월)
# 105. 제6회 청산생선국수축제  2025-04-05~2025-04-06  (4월)
# 106. 옥정호벚꽃축제  2025-04-06~2025-04-07  (4월)
# 107. 2025년 광복로 연등문화제  2025-04-07~2025-05-06  (4월)
# 108. 기지시줄다리기축제  2025-04-10~2025-04-13  (4월)
# 109. 제20회 창녕낙동강유채축제  2025-04-10~2025-04-13  (4월)
# 110. 제29회 청풍호 벚꽃축제  2025-04-10~2025-04-13  (4월)
# 111. 2025 가야문화축제  2025-04-11~2025-04-13  (4월)
# 112. 2025 보배섬 진도 유채꽃 축제  2025-04-11~2025-04-13  (4월)
# 113. 2025 행주가예술이야  2025-04-11~2025-04-27  (4월)
# 114. 두륜산 왕벚꽃나무 막걸리축제  2025-04-11~2025-04-12  (4월)
# 115. 산청 농특산물 대제전  2025-04-11~2025-04-13  (4월)
# 116. 수문통벚꽃행사  2025-04-11~2025-04-12  (4월)
# 117. 2025 평택꽃나들이  2025-04-12~2025-04-16  (4월)
# 118. 2025 회룡포 봄꽃축제  2025-04-12~2025-04-20  (4월)
# 119. 4·19혁명국민문화제  2025-04-12~2025-04-19  (4월)
# 120. 네번째 세종&연서 봄이왔나봄  2025-04-12~2025-04-13  (4월)
# 121. 봉산 딸기축제  2025-04-12~2025-04-12  (4월)
# 122. 인문학마을 축제  2025-04-12~2025-04-12  (4월)
# 123. 제17회 순성 벚꽃축제  2025-04-12~2025-04-13  (4월)
# 124. 제27회 부천 도당산 벚꽃축제  2025-04-12~2025-04-13  (4월)
# 125. 제2회 승기천 꽃피나 봄  2025-04-12~2025-04-13  (4월)
# 126. 제5회 수봉산 페스티벌  2025-04-12~2025-04-13  (4월)
# 127. 한강 불빛 공연(드론 라이트 쇼)  2025-04-12~2025-10-04  (4월)
# 128. 생초국제조각공원꽃잔디축제  2025-04-14~2025-04-27  (4월)
# 129. 2025 대전 사이언스페스티벌
# ○ (통합개최) (대전)제28회 대전사이언스페스티벌+(과기부)제29회 대한민국과학축제+대한민국과힉기술대전
# ○(예산내역) 총 38억원 /  대전시 16억, 과기부 22억(한국과학창의재단 12억, 한국연구재단 10억)
# ○(예상인원) 약 60만명 / 사이언스 30만명, 과학축제 30만명  2025-04-16~2025-04-20  (4월)
# 130. 2025년 팔금 섬 유채꽃축제  2025-04-16~2025-04-25  (4월)
# 131. 제15회 철마한우불고기축제  2025-04-17~2025-04-20  (4월)
# 132. 제22회 의령토요애수박축제  2025-04-17~2025-04-20  (4월)
# 133. 제50회 의령 홍의장군축제  2025-04-17~2025-04-20  (4월)
# 134. 2025 부여 세도 방울토마토&유채꽃 축제  2025-04-18~2025-04-20  (4월)
# 135. 2025 익산 문화유산야행  2025-04-18~2025-04-20  (4월)
# 136. 2025 화순 봄꽃 축제  2025-04-18~2025-04-27  (4월)
# 137. 우도 소라축제  2025-04-18~2025-04-20  (4월)
# 138. 제81회 지리산남악제 및 제44회 군민의 날 행사  2025-04-18~2025-04-20  (4월)
# 139. 2025 빵지순례 빵빵데이  2025-04-19~2025-04-20  (4월)
# 140. 갑사황매화축제  2025-04-19~2025-04-20  (4월)
# 141. 난설헌문화제  2025-04-19~2025-04-20  (4월)
# 142. 당진 삽교호 드론 라이트 쇼  2025-04-19~2025-11-01  (4월)
# 143. 도농 어울림 축제  2025-04-19~2025-10-19  (4월)
# 144. 섬 간재미축제  2025-04-19~2025-04-20  (4월)
# 145. 수원연등축제  2025-04-19~2025-04-19  (4월)
# 146. 제17회 정순왕후 문화제  2025-04-19~2025-04-19  (4월)
# 147. 제22회 청보리밭 축제  2025-04-19~2025-05-11  (4월)
# 148. 제3회 싸리산 축제  2025-04-19~2025-04-20  (4월)
# 149. 2025. 부활절 음악 대축제  2025-04-20~2025-04-20  (4월)
# 150. 청남대 봄꽃축제 '영춘제'  2025-04-24~2025-05-06  (4월)
# 151. 2025 고양국제꽃박람회  2025-04-25~2025-05-11  (4월)
# 152. 2025 금천 하모니축제  2025-04-25~2025-04-27  (4월)
# 153. 2025 조선통신사 축제  2025-04-25~2025-04-27  (4월)
# 154. 거제맹종대나무축제  2025-04-25~2025-04-27  (4월)
# 155. 그린 차박 페스티벌 in 울산  2025-04-25~2025-04-27  (4월)
# 156. 달빛 야외도서관  2025-04-25~2025-04-26  (4월)
# 157. 당항포대첩축제  2025-04-25~2025-04-27  (4월)
# 158. 마한문화축제  2025-04-25~2025-04-26  (4월)
# 159. 문화유산 야행  2025-04-25~2025-04-26  (4월)
# 160. 제15회 양평용문산 산나물축제  2025-04-25~2025-04-27  (4월)
# 161. 제27회 함평나비대축제  2025-04-25~2025-05-06  (4월)
# 162. 제28회 광주왕실도자페스티벌  2025-04-25~2025-05-06  (4월)
# 163. 제39회 이천도자기축제  2025-04-25~2025-05-06  (4월)
# 164. 제4회 계룡시 도시농업축제  2025-04-25~2025-04-26  (4월)
# 165. 제64회 아산 성웅 이순신축제  2025-04-25~2025-04-27  (4월)
# 166. 흑석산 소풍힐링축제  2025-04-25~2025-04-26  (4월)
# 167. 100+4 피아노섬 축제  2025-04-26~2025-04-27  (4월)
# 168. 2025 김제 모악뮤직페스티벌  2025-04-26~2025-04-27  (4월)
# 169. 2025년 대운산 철쭉제  2025-04-26~2025-04-26  (4월)
# 170. 목계별신제  2025-04-26~2025-04-27  (4월)
# 171. 산청황매산철쭉제  2025-04-26~2025-05-11  (4월)
# 172. 선사문화체험축제  2025-04-26~2025-04-27  (4월)
# 173. 신안 세계 김밥페스타  2025-04-26~2025-04-27  (4월)
# 174. 제29회 기장멸치축제  2025-04-26~2025-04-27  (4월)
# 175. 제29회 황매산철쭉제  2025-04-26~2025-05-11  (4월)
# 176. 제52회 윤봉길 평화축제  2025-04-26~2025-04-27  (4월)
# 177. 제6회 대한민국 함안 수박축제  2025-04-26~2025-04-28  (4월)
# 178. 황산 연호보리축제  2025-04-26~2025-04-26  (4월)
# 179. 서울페스타 2025  2025-04-30~2025-05-06  (4월)
# 180. 제95회 춘향제  2025-04-30~2025-05-06  (4월)
# 181. 서울페스타 2024  2024-05-01~2024-05-06  (5월)
# 182. 보성다향대축제  2024-05-02~2024-05-06  (5월)
# 183. 제18회 서울안전한마당  2024-05-02~2024-05-04  (5월)
# 184. 제19회 군산꽁당보리축제  2024-05-02~2024-05-04  (5월)
# 185. 제33회 안양예술제  2024-05-02~2024-05-02  (5월)
# 186. 한미친선 한마음 축제  2024-05-02~2024-05-02  (5월)
# 187. 2024 구리 유채꽃 축제  2024-05-03~2024-05-03  (5월)
# 188. 2024 예천활축제  2024-05-03~2024-05-06  (5월)
# 189. 2024 익산서동축제  2024-05-03~2024-05-06  (5월)
# 190. 2024 청춘양구 곰취축제  2024-05-03~2024-05-06  (5월)
# 191. 제11회 부안마실축제  2024-05-03~2024-05-06  (5월)
# 192. 제27회 광주왕실도자기축제  2024-05-03~2024-05-15  (5월)
# 193. 제2회 마이페스트  2024-05-03~2024-05-04  (5월)
# 194. 제31회 연천 구석기 축제  2024-05-03~2024-05-06  (5월)
# 195. 제36회 여주도자기축제  2024-05-03~2024-05-12  (5월)
# 196. 제39회 복사골예술제  2024-05-03~2024-05-05  (5월)
# 197. 조선통신사축제  2024-05-03~2024-05-05  (5월)
# 198. 차전장군노국공주축제  2024-05-03~2024-05-07  (5월)
# 199. 해남 공룡대축제  2024-05-03~2024-05-05  (5월)
# 200. 2024 가족의달 어린이축제  2024-05-04~2024-05-05  (5월)
# 201. 2024 보령.AMC 국제 모터페스티벌  2024-05-04~2024-05-06  (5월)
# 202. 의견문화제  2024-05-04~2024-05-06  (5월)
# 203. 의왕철도축제  2024-05-04~2024-05-05  (5월)
# 204. 제10회 황토갯벌축제  2024-05-04~2024-05-06  (5월)
# 205. 제13회 지평선 추억의 보리밭 축제  2024-05-04~2024-05-06  (5월)
# 206. 제20회 안산국제거리극축제  2024-05-04~2024-05-06  (5월)
# 207. 제21회 방선문축제  2024-05-04~2024-05-05  (5월)
# 208. 제24회 울산옹기축제  2024-05-04~2024-05-06  (5월)
# 209. 제2회 광산뮤직ON페스티벌  2024-05-04~2024-05-05  (5월)
# 210. 제58회 여수거북선축제  2024-05-04~2024-05-07  (5월)
# 211. 제5회 섬진강 슬로슬로 발효마을 축제  2024-05-04~2024-05-05  (5월)
# 212. 파주출판도시 어린이책잔치  2024-05-04~2024-05-06  (5월)
# 213. 제10회 대한민국 진도개페스티벌  2024-05-05~2024-05-06  (5월)
# 214. 제46회 대구약령시한방문화축제  2024-05-08~2024-05-12  (5월)
# 215. 제13회 대한민국와인축제  2024-05-09~2024-05-12  (5월)
# 216. 제19회 영양산나물축제  2024-05-09~2024-05-12  (5월)
# 217. 제63회 천령문화제  2024-05-09~2024-05-13  (5월)
# 218. 2024 금천하모니축제  2024-05-10~2024-05-12  (5월)
# 219. 2024 양주 회암사지 왕실축제  2024-05-10~2024-05-12  (5월)
# 220. 2024 유성온천문화축제  2024-05-10~2024-05-12  (5월)
# 221. 광안리어방축제  2024-05-10~2024-05-12  (5월)
# 222. 제10회 영광찰보리어울마당  2024-05-10~2024-05-11  (5월)
# 223. 제12회 도서관문화마당  2024-05-10~2024-05-11  (5월)
# 224. 제20회 울산쇠부리축제  2024-05-10~2024-05-12  (5월)
# 225. 제31회 물왕예술제  2024-05-10~2024-05-12  (5월)
# 226. 제57회 동학농민혁명기념제  2024-05-10~2024-05-11  (5월)
# 227. 제94회 춘향제  2024-05-10~2024-05-16  (5월)
# 228. 한강서래섬유채꽃축제  2024-05-10~2024-05-19  (5월)
# 229. 2024 조치원 봄꽃축제  2024-05-11~2024-05-12  (5월)
# 230. 대구생활문화제   2024-05-11~2024-05-12  (5월)
# 231. 제18회 보물섬 멸치축제  2024-05-11~2024-05-12  (5월)
# 232. 제27회 하동야생차문화축제  2024-05-11~2024-05-14  (5월)
# 233. 파워풀대구페스티벌  2024-05-11~2024-05-12  (5월)
# 234. 2024 계촌클래식축제  2024-05-15~2024-05-19  (5월)
# 235. 2024년 담양대나무축제  2024-05-15~2024-05-20  (5월)
# 236. 2024 성주참외&생명문화축제  2024-05-16~2024-05-19  (5월)
# 237. 2023 퍼플섬 라벤더 꽃축제  2024-05-17~2024-05-26  (5월)
# 238. 장미꽃 필 무렵  2024-05-17~2024-05-19  (5월)
# 239. 제14회 곡성세계장미축제  2024-05-17~2024-05-26  (5월)
# 240. 제22회 영천한약축제 with 작약꽃  2024-05-17~2024-05-19  (5월)
# 241. 제36회 고양행주문화제  2024-05-17~2024-05-19  (5월)
# 242. 제37회 지용제  2024-05-17~2024-05-19  (5월)
# 243. 태화강국가정원 봄꽃축제  2024-05-17~2024-05-19  (5월)
# 244. 2024 삼척 장미축제  2024-05-18~2024-05-22  (5월)
# 245. 제16회 울산대공원 장미축제  2024-05-22~2024-05-26  (5월)
# 246. 제25회 음성품바축제  2024-05-22~2024-05-26  (5월)
# 247. 제40회 단양 소백산철쭉제  2024-05-23~2024-05-26  (5월)
# 248. 제66회 밀양아리랑대축제  2024-05-23~2024-05-26  (5월)
# 249. 금정산성축제  2024-05-24~2024-05-26  (5월)
# 250. 문화재 야행 「밤하늘, 달콤한 문화산책」  2024-05-24~2024-05-25  (5월)
# 251. 영도커피페스티벌  2024-05-24~2024-05-26  (5월)
# 252. 정동야행축제  2024-05-24~2024-05-25  (5월)
# 253. 제18회 금사참외축제  2024-05-24~2024-05-26  (5월)
# 254. 제24회 서울대공원 장미원축제  2024-05-24~2024-06-09  (5월)
# 255. 제5회강남디자인위크  2024-05-24~2024-05-28  (5월)
# 256. 포천 인문學숲&북 페스티벌(가제)  2024-05-24~2024-05-25  (5월)
# 257. 해운대모래축제  2024-05-24~2024-05-27  (5월)
# 258. 황룡강 (洪)길동무 꽃길 축제  2024-05-24~2024-05-26  (5월)
# 259. 2024 Colorful Garden 자라섬 꽃 페스타(봄)  2024-05-25~2024-06-16  (5월)
# 260. 2024 서울세계도시문화축제  2024-05-25~2024-05-26  (5월)
# 261. 서울드럼페스티벌  2024-05-25~2024-05-26  (5월)
# 262. 세계인의 날 기념식 및 문화다양성축제  2024-05-25~2024-05-26  (5월)
# 263. 제27회 성호문화제  2024-05-25~2024-05-26  (5월)
# 264. 제29회 대덕제 「대구앞산축제」  2024-05-25~2024-05-26  (5월)
# 265. 2024 포천아트밸리 뮤직페스티벌 (PAMF)  2024-05-26~2024-05-27  (5월)
# 266. 춘천마임축제  2024-05-26~2024-06-02  (5월)
# 267. 충주다이브페스티벌  2024-05-30~2024-06-02  (5월)
# 268. 제14회 화성뱃놀이 축제  2024-05-31~2024-06-02  (5월)
# 269. 천변라이프 강북페스타2024  2024-05-31~2024-06-02  (5월)
# 270. 포천 축산 그랜드페스티벌  2024-05-31~2024-06-02  (5월)
# 271. 포항국제불빛축제  2024-05-31~2024-06-02  (5월)
# 272. 2025 차전장군노국공주축제  2025-05-01~2025-05-06  (5월)
# 273. 우산동 하이볼 축제  2025-05-01~2025-05-31  (5월)
# 274. 제19회 서울안전한마당  2025-05-01~2025-05-03  (5월)
# 275. 제27회 와룡문화제  2025-05-01~2025-05-04  (5월)
# 276. 제37회 여주도자기축제  2025-05-01~2025-05-11  (5월)
# 277. 2025 예천활축제  2025-05-02~2025-05-05  (5월)
# 278. 2025 유성온천문화축제  2025-05-02~2025-05-04  (5월)
# 279. 2025 전주세계문화주간  2025-05-02~2025-05-08  (5월)
# 280. 2025 청주시 도시농업 페스티벌  2025-05-02~2025-05-05  (5월)
# 281. 제12회 부안마실축제  2025-05-02~2025-05-05  (5월)
# 282. 제20회 군산꽁당보리축제  2025-05-02~2025-05-05  (5월)
# 283. 제22회 정남진장흥 키조개축제  2025-05-02~2025-05-06  (5월)
# 284. 제32회 연천 구석기 축제  2025-05-02~2025-05-05  (5월)
# 285. 제34회 안양예술제  2025-05-02~2025-05-03  (5월)
# 286. 제3회 중앙시장 주말축제
# 야시장 '동구夜놀자'  2025-05-02~2025-10-04  (5월)
# 287. 제40회 복사골예술제  2025-05-02~2025-05-05  (5월)
# 288. 제48회 보성다향대축제  2025-05-02~2025-05-06  (5월)
# 289. 한강 서래섬 유채꽃 축제  2025-05-02~2025-05-11  (5월)
# 290. 2025 완도장보고수산물축제  2025-05-03~2025-05-06  (5월)
# 291. 2025 책읽는 한강공원  2025-05-03~2025-10-25  (5월)
# 292. 2025 청춘양구 곰취축제  2025-05-03~2025-05-06  (5월)
# 293. 2025년 익산서동축제  2025-05-03~2025-05-06  (5월)
# 294. 2025년 포천 농특산물 대축제(상반기)  2025-05-03~2025-06-15  (5월)
# 295. 공주 석장리 구석기축제  2025-05-03~2025-05-06  (5월)
# 296. 마곡사 신록축제  2025-05-03~2025-05-05  (5월)
# 297. 보령.AMC 국제모터 페스티벌  2025-05-03~2025-05-05  (5월)
# 298. 삼람성, 평화로 물들다
# (강화도 별별야행)  2025-05-03~2025-05-05  (5월)
# 299. 의견문화제(임실N펫스타)  2025-05-03~2025-05-05  (5월)
# 300. 의왕어린이철도축제  2025-05-03~2025-05-03  (5월)
# ... (168개 더 있음)
