# %%
# -*- coding: utf-8 -*-
"""
🎯 (2024+2025) 축제명 + 기준 월 → 같은 '계절(절기형)'에 열리는 축제만 리스트업 (유사시기 단일 필터)
- 계절 규칙: 3/4/5 → [3,4,5], 6/7/8 → [6,7,8], 9/10/11 → [9,10,11], 12/1/2 → [12,1,2]
- 로드: ./csv/{2024,2025}_축제_핵심필드.csv (+ /mnt/data 경로도 시도)
- 아직 시작 안 한 축제(시작일 > 오늘) 제외
- 입력 축제명(정확·유사) 제외
- 출력: 기본 "축제명  (표시월)" / show_period=True면 "축제명  시작일~종료일  (표시월)"
"""

import os, re
from pathlib import Path
from typing import Optional, List, Set, Dict

import pandas as pd
from difflib import get_close_matches

# ---------------- Settings --------------------
CANDIDATE_FILES = [
    "./csv/2024_축제_핵심필드.csv",
    "./csv/2025_축제_핵심필드.csv",
    "/mnt/data/2024_축제_핵심필드.csv",
    "/mnt/data/2025_축제_핵심필드.csv",
]

# ---------------- Utils -----------------------
def normalize_text(s: str) -> str:
    if s is None: return ""
    s = str(s).strip().replace("\xa0", " ")
    return re.sub(r"\s+", "", s)

def parse_date_str(s: str) -> Optional[pd.Timestamp]:
    try:
        return pd.to_datetime(str(s), format="%Y-%m-%d", errors="coerce")
    except Exception:
        return None

def today_floor_ts() -> pd.Timestamp:
    return pd.Timestamp.today().normalize()

def standardize_columns(df: pd.DataFrame) -> pd.DataFrame:
    """'축제유형' -> '축제 유형' 등 표준화 (유형은 쓰지 않지만 스키마 정합성용)."""
    colmap = {}
    for c in df.columns:
        cc = str(c).strip()
        if cc == "축제유형":
            colmap[c] = "축제 유형"
    return df.rename(columns=colmap)

def ensure_columns(df: pd.DataFrame) -> pd.DataFrame:
    df = standardize_columns(df)
    needed = ["연번", "광역자치단체명", "기초자치단체명", "축제명", "시작일", "종료일"]
    for c in needed:
        if c not in df.columns:
            raise ValueError(f"필수 컬럼 누락: {c}")
    return df

def read_many_csv(paths: List[str]) -> pd.DataFrame:
    frames = []
    for p in paths:
        if Path(p).exists():
            try:
                df = pd.read_csv(p, dtype=str).fillna("")
            except UnicodeDecodeError:
                df = pd.read_csv(p, dtype=str, encoding="utf-8-sig").fillna("")
            df = ensure_columns(df)
            df["_출처파일"] = Path(p).name
            frames.append(df)
    if not frames:
        raise FileNotFoundError("입력 CSV를 하나도 찾지 못했습니다.")
    out = pd.concat(frames, ignore_index=True)
    out = out.drop_duplicates(
        subset=["광역자치단체명","기초자치단체명","축제명","시작일","종료일"],
        keep="first"
    ).reset_index(drop=True)
    return out

def months_in_range(start: Optional[pd.Timestamp], end: Optional[pd.Timestamp]) -> Set[int]:
    """시작~종료 사이의 월(1..12) 집합. 연도 넘어가도 월만 모음."""
    if (start is None or pd.isna(start)) or (end is None or pd.isna(end)):
        return set()
    if end < start:
        start, end = end, start
    months = set()
    cur = pd.Timestamp(year=start.year, month=start.month, day=1)
    last = pd.Timestamp(year=end.year, month=end.month, day=1)
    while cur <= last:
        months.add(int(cur.month))
        if cur.month == 12:
            cur = pd.Timestamp(year=cur.year + 1, month=1, day=1)
        else:
            cur = pd.Timestamp(year=cur.year, month=cur.month + 1, day=1)
    return months

def circular_month_distance(a: int, b: int) -> int:
    a, b = int(a), int(b)
    d = abs(a - b)
    return min(d, 12 - d)

# 계절 매핑: 3‒5 / 6‒8 / 9‒11 / 12‒2
def season_months(pivot_month: int) -> List[int]:
    m = int(pivot_month)
    if m in (3,4,5):   return [3,4,5]     # 봄
    if m in (6,7,8):   return [6,7,8]     # 여름
    if m in (9,10,11): return [9,10,11]   # 가을
    return [12,1,2]                       # 겨울 (연도 넘김)

# ---------------- Core ------------------------
def load_data(csv_path_override: Optional[str] = None) -> pd.DataFrame:
    if csv_path_override and Path(csv_path_override).exists():
        try:
            df = pd.read_csv(csv_path_override, dtype=str).fillna("")
        except UnicodeDecodeError:
            df = pd.read_csv(csv_path_override, dtype=str, encoding="utf-8-sig").fillna("")
        df = ensure_columns(df)
        df["_출처파일"] = Path(csv_path_override).name
        return df
    return read_many_csv(CANDIDATE_FILES)

def filter_by_season_time_only(
    df: pd.DataFrame,
    query_name: str,
    pivot_month: int,
) -> pd.DataFrame:
    """유사 시기(계절)만으로 필터링."""
    smonths = season_months(pivot_month)
    smonths_set = set(smonths)

    # 날짜 파싱 + 아직 시작 안 한 축제 제외
    today = today_floor_ts()
    df = df.copy()
    df["시작일_dt"] = df["시작일"].apply(parse_date_str)
    df["종료일_dt"] = df["종료일"].apply(parse_date_str)
    df = df[(~df["시작일_dt"].isna()) & (~df["종료일_dt"].isna()) & (df["시작일_dt"] <= today)]

    # 입력 축제명(정확·유사) 제외
    inorm = normalize_text(query_name)
    all_names = df["축제명"].astype(str).tolist()
    close = set(get_close_matches(query_name, all_names, n=3, cutoff=0.85))
    def _is_self(x: str) -> bool:
        nx = normalize_text(x)
        return (nx == inorm) or (x in close)
    df = df[~df["축제명"].astype(str).apply(_is_self)]

    # 계절과 겹치는 월이 있는 축제만 남김
    def _keep(row) -> bool:
        rng = months_in_range(row["시작일_dt"], row["종료일_dt"])
        return len(rng & smonths_set) > 0
    df = df[df.apply(_keep, axis=1)].copy()

    # 표시월: 계절 교집합 중 pivot에 가장 가까운 월 (원형 거리)
    df["시작월"] = df["시작일_dt"].dt.month.astype(int)
    def _display_month(row) -> int:
        rng = months_in_range(row["시작일_dt"], row["종료일_dt"]) & smonths_set
        if not rng:
            return int(row["시작월"])
        if pivot_month in rng:
            return int(pivot_month)
        return sorted(list(rng), key=lambda m: circular_month_distance(m, pivot_month))[0]
    df["표시월"] = df.apply(_display_month, axis=1).astype(int)

    # 계절 내부 자연스러운 순서(예: 겨울 12→1→2)로 정렬
    order_map = {m:i for i,m in enumerate(smonths, start=1)}
    df["_mo_order"] = df["표시월"].map(order_map).fillna(99)

    df = df.sort_values(by=["_mo_order","시작일_dt","축제명"]).drop(columns=["_mo_order"]).reset_index(drop=True)
    return df[["광역자치단체명","기초자치단체명","축제명","시작일","종료일","표시월","_출처파일"]]

# ---------------- Runner -----------------------
def run_timeonly_season(
    festival_name: str,
    pivot_month: int,
    csv_path_override: Optional[str] = None,
    print_limit: int = 300,
    dedupe: bool = True,
    show_period: bool = False,  # True면 "이름  시작~종료 (표시월)"
):
    df = load_data(csv_path_override)
    out = filter_by_season_time_only(df, festival_name, int(pivot_month))

    # 중복 이름 제거(원하면)
    if dedupe and not out.empty:
        out = out.drop_duplicates(subset=["축제명"], keep="first")

    # 출력
    print(f"입력 축제명: {festival_name} | 기준 월: {pivot_month} → 계절월={season_months(pivot_month)}")
    rows = []
    for _, r in out.iterrows():
        if show_period:
            rows.append(f"{r['축제명']}  {r['시작일']}~{r['종료일']}  ({int(r['표시월'])}월)")
        else:
            rows.append(f"{r['축제명']}  ({int(r['표시월'])}월)")

    print(f"\n같은 계절(유사시기) 축제 수: {len(rows)}")
    if rows:
        print("\n[목록]")
        for i, line in enumerate(rows[:print_limit], start=1):
            print(f"{i:>3}. {line}")
        if len(rows) > print_limit:
            print(f"... ({len(rows)-print_limit}개 더 있음)")
    return out

# ------------- Example -------------
if __name__ == "__main__":
    # 예: '담양산타축제', 12월 기준 → 겨울(12,1,2) 유사시기만
    run_timeonly_season("홍어축제", pivot_month=4, show_period=True)
    # run_timeonly_season("임실 산타축제", pivot_month=1, show_period=False)
# Out:
# 입력 축제명: 홍어축제 | 기준 월: 4 → 계절월=[3, 4, 5]
#
# 같은 계절(유사시기) 축제 수: 498
#
# [목록]
#   1. 배내골고로쇠축제  2024-02-15~2024-03-15  (3월)
#   2. 백련사 동백축제  2024-02-23~2024-03-03  (3월)
#   3. 제52회 강진청자축제  2024-02-23~2024-03-03  (3월)
#   4. 제27회 영덕대게축제  2024-02-29~2024-03-03  (3월)
#   5. 제63회 3.1민속문화제  2024-02-29~2024-03-03  (3월)
#   6. 동래 3.1만세운동재현행사  2024-03-01~2024-03-01  (3월)
#   7. 논산딸기축제  2024-03-04~2024-03-04  (3월)
#   8. 영흥풍어기원제  2024-03-04~2024-03-04  (3월)
#   9. 제23회 광양매화축제  2024-03-08~2024-03-17  (3월)
#  10. 동구 3.1절 기념 행사  2024-03-09~2024-03-09  (3월)
#  11. 원동매화축제  2024-03-09~2024-03-17  (3월)
#  12. 제17회 산수유마을꽃맞이행사  2024-03-09~2024-03-09  (3월)
#  13. 제20회 진안고원 운장산 고로쇠 축제  2024-03-09~2024-03-10  (3월)
#  14. 제25회 구례산수유꽃축제  2024-03-09~2024-03-17  (3월)
#  15. 제44회 진도신비의바닷길축제  2024-03-11~2024-03-13  (3월)
#  16. 연제고분판타지축제  2024-03-22~2024-03-24  (3월)
#  17. 2024 대한민국 난명품 대제전  2024-03-23~2024-03-24  (3월)
#  18. 대저토마토축제  2024-03-23~2024-03-24  (3월)
#  19. 제32회 여수영취산진달래축제  2024-03-23~2024-03-24  (3월)
#  20. 영암왕인문화축제  2024-03-28~2024-03-31  (3월)
#  21. 2024 구례300리 벚꽃축제  2024-03-29~2024-03-31  (3월)
#  22. 2024 꽃빛드리축제  2024-03-29~2024-03-31  (3월)
#  23. 2024 유달산 봄 축제  2024-03-29~2024-03-31  (3월)
#  24. 강서 낙동강30리 벚꽃축제  2024-03-29~2024-03-31  (3월)
#  25. 고령대가야축제  2024-03-29~2024-03-31  (3월)
#  26. 구포장터 3.1만세운동기념행사  2024-03-29~2024-03-29  (3월)
#  27. 남해대교 문화행사 "노량의 봄"  2024-03-29~2024-03-30  (3월)
#  28. 대청호 봄축제(가칭)  2024-03-29~2024-03-31  (3월)
#  29. 제18회 정선 동강할미꽃 축제  2024-03-29~2024-03-31  (3월)
#  30. 제22회 옥천묘목축제  2024-03-29~2024-03-31  (3월)
#  31. 제29회 부곡온천축제  2024-03-29~2024-03-31  (3월)
#  32. 제2회 고창 벚꽃축제  2024-03-29~2024-03-31  (3월)
#  33. 동대문구 봄꽃축제  2024-03-30~2024-03-31  (3월)
#  34. 삼락벚꽃축제  2024-03-30~2024-03-31  (3월)
#  35. 설악벚꽃축제  2024-03-30~2024-03-31  (3월)
#  36. 제24회 진달래축제  2024-03-30~2024-03-31  (3월)
#  37. 제26회 부천 도당산 벚꽃축제  2024-03-30~2024-03-31  (3월)
#  38. 제41회 서귀포유채꽃축제  2024-03-30~2024-03-31  (3월)
#  39. 제5회 선진리성벚꽃축제  2024-03-30~2024-03-31  (3월)
#  40. 2025 원동미나리축제  2025-02-22~2025-03-31  (3월)
#  41. 제53회 강진청자축제  2025-02-22~2025-03-03  (3월)
#  42. 2025 울진대게와 붉은대게축제  2025-02-28~2025-03-03  (3월)
#  43. 2025 제천빨간오뎅축제  2025-02-28~2025-03-03  (3월)
#  44. 제64회 3.1민속문화제  2025-02-28~2025-03-03  (3월)
#  45. 2025 원동매화축제  2025-03-01~2025-03-03  (3월)
#  46. 계룡산 벚꽃축제  2025-03-01~2025-03-16  (3월)
#  47. 동래3.1만세운동재현행사  2025-03-01~2025-03-01  (3월)
#  48. 2025 3·3데이 청주삼겹살 축제  2025-03-02~2025-03-03  (3월)
#  49. 2025 섬 홍매화축제  2025-03-07~2025-03-09  (3월)
#  50. 제 20회 (사)전라남도 연합회 정남진 난꽃축제  2025-03-07~2025-03-08  (3월)
#  51. 제 23회 완주 삼례딸기축제  2025-03-07~2025-03-09  (3월)
#  52. 제24회 광양매화축제  2025-03-07~2025-03-16  (3월)
#  53. 제21회 진안고원 운장산 고로쇠축제  2025-03-08~2025-03-09  (3월)
#  54. 제2회 MY아리나드림페스티벌  2025-03-08~2025-03-30  (3월)
#  55. 2025 제주들불축제  2025-03-14~2025-03-16  (3월)
#  56. 제28회 영덕대게축제  2025-03-14~2025-03-17  (3월)
#  57. 제26회 구례산수유꽃축제  2025-03-15~2025-03-23  (3월)
#  58. 제26회 양평단월고로쇠축제  2025-03-15~2025-03-16  (3월)
#  59. 동백꽃 주꾸미 축제  2025-03-16~2025-03-30  (3월)
#  60. 정선동강할미꽃축제  2025-03-21~2025-03-23  (3월)
#  61. 달마고도 힐링축제  2025-03-22~2025-03-22  (3월)
#  62. 제18회 산수유마을 꽃맞이 행사  2025-03-22~2025-03-30  (3월)
#  63. 제33회 영취산 진달래축제  2025-03-22~2025-03-23  (3월)
#  64. 2025 고향사랑 방문의 해 기념 "꽃 피는 남해"  2025-03-28~2025-03-29  (3월)
#  65. 2025 구례300리 벚꽃축제  2025-03-28~2025-03-30  (3월)
#  66. 2025 낙동강정원 벚꽃축제  2025-03-28~2025-03-30  (3월)
#  67. 2025 벚꽃과 함께하는 제3회 청주 푸드트럭 축제  2025-03-28~2025-03-30  (3월)
#  68. 2025년 동구 봄축제  2025-03-28~2025-03-29  (3월)
#  69. 고령 대가야축제  2025-03-28~2025-03-30  (3월)
#  70. 제18회 전농로 왕벚꽃축제  2025-03-28~2025-03-30  (3월)
#  71. 제23회 옥천묘목축제  2025-03-28~2025-03-30  (3월)
#  72. 제27회 화개장터 벚꽃축제  2025-03-28~2025-03-30  (3월)
#  73. 제28회 전라병영성축제  2025-03-28~2025-03-30  (3월)
#  74. 제30회 부곡온천축제  2025-03-28~2025-03-30  (3월)
#  75. 제6회 연제고분판타지축제  2025-03-28~2025-03-30  (3월)
#  76. 충주호 벚꽃축제  2025-03-28~2025-03-30  (3월)
#  77. 2025 물금벚꽃축제  2025-03-29~2025-03-30  (3월)
#  78. 2025 벚꽃에 물든 상상주도 비박페스티벌  2025-03-29~2025-03-30  (3월)
#  79. 궁거랑 벚꽃 한마당  2025-03-29~2025-03-30  (3월)
#  80. 남원 봄꾳 문화재  2025-03-29~2025-03-30  (3월)
#  81. 부천 원미산 진달래 축제  2025-03-29~2025-03-30  (3월)
#  82. 제20회 봉숫골꽃나들이 축제  2025-03-29~2025-03-30  (3월)
#  83. 제22회 산수유한우축제  2025-03-29~2025-03-30  (3월)
#  84. 제42회 서귀포유채꽃축제  2025-03-29~2025-03-30  (3월)
#  85. 제6회 선진리성 벚꽃축제  2025-03-29~2025-03-30  (3월)
#  86. 주산 벚꽃축제  2025-03-29~2025-03-30  (3월)
#  87. 호미반도 유채꽃 개장식  2025-03-29~2025-03-30  (3월)
#  88. 제62회 진해군항제
# (군악의장페스티벌)  2024-03-23~2024-04-01  (4월)
#  89. 2024 경포 벚꽃 축제  2024-03-29~2024-04-03  (4월)
#  90. 2024년 섬수선화축제  2024-03-29~2024-04-07  (4월)
#  91. 정읍 벚꽃축제  2024-03-29~2024-04-01  (4월)
#  92. 청춘, 금오천 벚꽃 페스티벌  2024-03-30~2024-04-02  (4월)
#  93. 강남동 새봄맞이 축제  2024-03-31~2024-04-02  (4월)
#  94. 제2회 십승지명당운본고원벚꽃축제  2024-04-01~2024-04-01  (4월)
#  95. 금성면 제1회 고비산 산벚꽃축제  2024-04-02~2024-04-02  (4월)
#  96. 안양충훈벚꽃축제  2024-04-02~2024-04-02  (4월)
#  97. 제28회 비슬산 참꽃 문화제  2024-04-02~2024-04-02  (4월)
#  98. 제2회 남대천 벚꽃축제  2024-04-02~2024-04-02  (4월)
#  99. 우이천 벚꽃 축제  2024-04-03~2024-04-07  (4월)
# 100. 2024 보은 벚꽃길 축제  2024-04-05~2024-04-07  (4월)
# 101. 2024 섬 튤립축제  2024-04-05~2024-04-14  (4월)
# 102. 제8회여주흥천남한강벚꽃축제  2024-04-05~2024-04-07  (4월)
# 103. 2024 영랑호 벚꽃축제  2024-04-06~2024-04-07  (4월)
# 104. 2024년 인천대공원 벚꽃축제  2024-04-06~2024-04-07  (4월)
# 105. 제20회삼척맹방유채꽃축제  2024-04-06~2024-04-14  (4월)
# 106. 제19회 창녕낙동강유채축제  2024-04-11~2024-04-14  (4월)
# 107. 419혁명국민문화제  2024-04-12~2024-04-19  (4월)
# 108. 동해항 크랩킹페스타  2024-04-12~2024-04-14  (4월)
# 109. 제12회 장봉도 벚꽃축제  2024-04-13~2024-04-13  (4월)
# 110. 제2회 전국 새우란 축제  2024-04-16~2024-04-21  (4월)
# 111. 제49회 의령 홍의장군축제  2024-04-18~2024-04-21  (4월)
# 112. 2024 사천시 삼천포항
# 수산물축제  2024-04-19~2024-04-21  (4월)
# 113. 2024 익산 문화유산야행  2024-04-19~2024-04-21  (4월)
# 114. 2024 화순 고인돌 축제  2024-04-19~2024-04-28  (4월)
# 115. 2024년 가야문화축제  2024-04-19~2024-04-23  (4월)
# 116. 2024년 밀양 문화유산 야행  2024-04-19~2024-04-21  (4월)
# 117. 제21회 청도소싸움축제  2024-04-19~2024-04-21  (4월)
# 118. 제4회 강진 성전월출산 봄소풍가는날  2024-04-19~2024-04-21  (4월)
# 119. 제80회 지리산남악제 및 43회 군민의 날 행사  2024-04-19~2024-04-21  (4월)
# 120. 고창 청보리밭축제  2024-04-20~2024-05-12  (4월)
# 121. 군포철쭉축제  2024-04-20~2024-04-28  (4월)
# 122. 선농대제  2024-04-20~2024-04-20  (4월)
# 123. 지평선광활햇감자축제  2024-04-20~2024-04-21  (4월)
# 124. 평택 꽃 나들이  2024-04-20~2024-04-24  (4월)
# 125. 2024 광주 문화유산 야행 '돌의 기억'  2024-04-26~2024-04-27  (4월)
# 126. 2024 대한민국 과학축제  2024-04-26~2024-04-28  (4월)
# 127. 2024고양국제꽃박람회  2024-04-26~2024-05-12  (4월)
# 128. 거제맹종대나무 축제  2024-04-26~2024-04-28  (4월)
# 129. 단종문화제  2024-04-26~2024-04-28  (4월)
# 130. 제13회 우도소라축제  2024-04-26~2024-04-28  (4월)
# 131. 제14회 용문산 산나물 축제  2024-04-26~2024-04-28  (4월)
# 132. 제17회 김제모락페스티벌  2024-04-26~2024-04-27  (4월)
# 133. 제26회 사천와룡문화제  2024-04-26~2024-04-28  (4월)
# 134. 제26회 함평나비대축제  2024-04-26~2024-05-05  (4월)
# 135. 제5회 대한민국 & 제30회 함안수박축제  2024-04-26~2024-04-28  (4월)
# 136. 제6회 창선고사리축제  2024-04-26~2024-04-27  (4월)
# 137. 태백 천상의 산나물축제  2024-04-26~2024-04-28  (4월)
# 138. 흑석산 소풍 힐링축제  2024-04-26~2024-04-27  (4월)
# 139. 가산산성 문화유산 야행  2024-04-27~2024-04-28  (4월)
# 140. 제26회 문경찻사발축제  2024-04-27~2024-05-06  (4월)
# 141. 제27회 동춘당문화제  2024-04-27~2024-04-27  (4월)
# 142. 포항해병대문화축제  2024-04-27~2024-04-28  (4월)
# 143. 2024 섬 겨울꽃 축제  2024-12-06~2024-01-01  (4월)
# 144. 상주 해돋이&물메기 축제  2024-12-31~2024-01-01  (4월)
# 145. 왜목마을해넘이해돋이소원제  2024-12-31~2024-01-01  (4월)
# 146. 포항 구룡포 과메기&겨울바다 축제  2024-12-31~2024-01-01  (4월)
# 147. 호미곶한민족해맞이축전  2024-12-31~2024-01-01  (4월)
# 148. 홍성 남당항 새조개와 함께하는 수산물축제  2025-02-07~2025-04-07  (4월)
# 149. 무창포 주꾸미 도다리 축제  2025-03-22~2025-04-13  (4월)
# 150. 제21회 삼척맹방유채꽃축제  2025-03-27~2025-04-20  (4월)
# 151. 2025 대덕물빛축제  2025-03-28~2025-04-26  (4월)
# 152. 2025년 섬 수선화축제  2025-03-28~2025-04-06  (4월)
# 153. 경포 벚꽃 축제  2025-03-28~2025-04-02  (4월)
# 154. 도봉 벚꽃축제  2025-03-28~2025-04-03  (4월)
# 155. 2025 연화지 벚꽃 페스타  2025-03-29~2025-04-06  (4월)
# 156. 부천 페스타(B-festa)-봄꽃여행  2025-03-29~2025-04-06  (4월)
# 157. 서대문봄빛축제  2025-03-29~2025-04-06  (4월)
# 158. 제26회 영암왕인문화축제  2025-03-29~2025-04-06  (4월)
# 159. 제45회 진도신비의바닷길축제  2025-03-29~2025-04-01  (4월)
# 160. 제63회 진해군항제  2025-03-29~2025-04-06  (4월)
# 161. 제6회 울주작천정벚꽃축제  2025-03-29~2025-04-06  (4월)
# 162. 제7회 대청호 벚꽃축제(가칭)  2025-03-29~2025-04-06  (4월)
# 163. 제12회 보성벚꽃축제  2025-03-31~2025-04-01  (4월)
# 164. 우산지락  2025-04-01~2025-10-31  (4월)
# 165. 송파구 벚꽃축제  2025-04-02~2025-04-06  (4월)
# 166. 2025 벚꽃축제  2025-04-03~2025-04-07  (4월)
# 167. 2025 꽃빛드리축제  2025-04-04~2025-04-06  (4월)
# 168. 2025 만석거 새빛 축제  2025-04-04~2025-04-13  (4월)
# 169. 2025 보은벚꽃길축제  2025-04-04~2025-04-13  (4월)
# 170. 2025 섬 튤립축제  2025-04-04~2025-04-13  (4월)
# 171. 2025 양양 생태생명축제  2025-04-04~2025-04-13  (4월)
# 172. 제10회 사천비토섬별주부전축제  2025-04-04~2025-04-05  (4월)
# 173. 제12회 전천축제  2025-04-04~2025-04-06  (4월)
# 174. 제1회 면천의 봄  2025-04-04~2025-04-06  (4월)
# 175. 제3회 고창 벚꽃축제  2025-04-04~2025-04-06  (4월)
# 176. 제8회 갈산누리봄축제  2025-04-04~2025-04-06  (4월)
# 177. 제9회여주흥천남한강벚꽃축제  2025-04-04~2025-04-06  (4월)
# 178. 2025 안양충훈벚꽃축제  2025-04-05~2025-04-06  (4월)
# 179. 2025 유달산 봄축제  2025-04-05~2025-04-06  (4월)
# 180. 2025 청산도슬로걷기축제  2025-04-05~2025-05-04  (4월)
# 181. 2025년 인천대공원 벚꽃축제  2025-04-05~2025-04-06  (4월)
# 182. 2025년 조치원 봄꽃축제  2025-04-05~2025-04-06  (4월)
# 183. 고려산 진달래꽃구경  2025-04-05~2025-04-13  (4월)
# 184. 김포 벚꽃축제  2025-04-05~2025-04-06  (4월)
# 185. 제11회 이천체험문화축제  2025-04-05~2025-04-06  (4월)
# 186. 제1회 숭어축제  2025-04-05~2025-04-06  (4월)
# 187. 제1회 슬도 봄꽃 축제  2025-04-05~2025-04-06  (4월)
# 188. 제25회 농다리 축제  2025-04-05~2025-06-01  (4월)
# 189. 제3회 남대천 벚꽃축제  2025-04-05~2025-04-06  (4월)
# 190. 제3회 완주 모악산 웰니스축제  2025-04-05~2025-04-06  (4월)
# 191. 제6회 청산생선국수축제  2025-04-05~2025-04-06  (4월)
# 192. 옥정호벚꽃축제  2025-04-06~2025-04-07  (4월)
# 193. 2025년 광복로 연등문화제  2025-04-07~2025-05-06  (4월)
# 194. 기지시줄다리기축제  2025-04-10~2025-04-13  (4월)
# 195. 제20회 창녕낙동강유채축제  2025-04-10~2025-04-13  (4월)
# 196. 제29회 청풍호 벚꽃축제  2025-04-10~2025-04-13  (4월)
# 197. 2025 가야문화축제  2025-04-11~2025-04-13  (4월)
# 198. 2025 보배섬 진도 유채꽃 축제  2025-04-11~2025-04-13  (4월)
# 199. 2025 행주가예술이야  2025-04-11~2025-04-27  (4월)
# 200. 두륜산 왕벚꽃나무 막걸리축제  2025-04-11~2025-04-12  (4월)
# 201. 산청 농특산물 대제전  2025-04-11~2025-04-13  (4월)
# 202. 수문통벚꽃행사  2025-04-11~2025-04-12  (4월)
# 203. 2025 평택꽃나들이  2025-04-12~2025-04-16  (4월)
# 204. 2025 회룡포 봄꽃축제  2025-04-12~2025-04-20  (4월)
# 205. 4·19혁명국민문화제  2025-04-12~2025-04-19  (4월)
# 206. 네번째 세종&연서 봄이왔나봄  2025-04-12~2025-04-13  (4월)
# 207. 봉산 딸기축제  2025-04-12~2025-04-12  (4월)
# 208. 인문학마을 축제  2025-04-12~2025-04-12  (4월)
# 209. 제17회 순성 벚꽃축제  2025-04-12~2025-04-13  (4월)
# 210. 제27회 부천 도당산 벚꽃축제  2025-04-12~2025-04-13  (4월)
# 211. 제2회 승기천 꽃피나 봄  2025-04-12~2025-04-13  (4월)
# 212. 제5회 수봉산 페스티벌  2025-04-12~2025-04-13  (4월)
# 213. 한강 불빛 공연(드론 라이트 쇼)  2025-04-12~2025-10-04  (4월)
# 214. 생초국제조각공원꽃잔디축제  2025-04-14~2025-04-27  (4월)
# 215. 2025 대전 사이언스페스티벌
# ○ (통합개최) (대전)제28회 대전사이언스페스티벌+(과기부)제29회 대한민국과학축제+대한민국과힉기술대전
# ○(예산내역) 총 38억원 /  대전시 16억, 과기부 22억(한국과학창의재단 12억, 한국연구재단 10억)
# ○(예상인원) 약 60만명 / 사이언스 30만명, 과학축제 30만명  2025-04-16~2025-04-20  (4월)
# 216. 2025년 팔금 섬 유채꽃축제  2025-04-16~2025-04-25  (4월)
# 217. 제15회 철마한우불고기축제  2025-04-17~2025-04-20  (4월)
# 218. 제22회 의령토요애수박축제  2025-04-17~2025-04-20  (4월)
# 219. 제50회 의령 홍의장군축제  2025-04-17~2025-04-20  (4월)
# 220. 2025 부여 세도 방울토마토&유채꽃 축제  2025-04-18~2025-04-20  (4월)
# 221. 2025 익산 문화유산야행  2025-04-18~2025-04-20  (4월)
# 222. 2025 화순 봄꽃 축제  2025-04-18~2025-04-27  (4월)
# 223. 우도 소라축제  2025-04-18~2025-04-20  (4월)
# 224. 제81회 지리산남악제 및 제44회 군민의 날 행사  2025-04-18~2025-04-20  (4월)
# 225. 2025 빵지순례 빵빵데이  2025-04-19~2025-04-20  (4월)
# 226. 갑사황매화축제  2025-04-19~2025-04-20  (4월)
# 227. 난설헌문화제  2025-04-19~2025-04-20  (4월)
# 228. 당진 삽교호 드론 라이트 쇼  2025-04-19~2025-11-01  (4월)
# 229. 도농 어울림 축제  2025-04-19~2025-10-19  (4월)
# 230. 섬 간재미축제  2025-04-19~2025-04-20  (4월)
# 231. 수원연등축제  2025-04-19~2025-04-19  (4월)
# 232. 제17회 정순왕후 문화제  2025-04-19~2025-04-19  (4월)
# 233. 제22회 청보리밭 축제  2025-04-19~2025-05-11  (4월)
# 234. 제3회 싸리산 축제  2025-04-19~2025-04-20  (4월)
# 235. 2025. 부활절 음악 대축제  2025-04-20~2025-04-20  (4월)
# 236. 청남대 봄꽃축제 '영춘제'  2025-04-24~2025-05-06  (4월)
# 237. 2025 고양국제꽃박람회  2025-04-25~2025-05-11  (4월)
# 238. 2025 금천 하모니축제  2025-04-25~2025-04-27  (4월)
# 239. 2025 조선통신사 축제  2025-04-25~2025-04-27  (4월)
# 240. 거제맹종대나무축제  2025-04-25~2025-04-27  (4월)
# 241. 그린 차박 페스티벌 in 울산  2025-04-25~2025-04-27  (4월)
# 242. 달빛 야외도서관  2025-04-25~2025-04-26  (4월)
# 243. 당항포대첩축제  2025-04-25~2025-04-27  (4월)
# 244. 마한문화축제  2025-04-25~2025-04-26  (4월)
# 245. 문화유산 야행  2025-04-25~2025-04-26  (4월)
# 246. 제15회 양평용문산 산나물축제  2025-04-25~2025-04-27  (4월)
# 247. 제27회 함평나비대축제  2025-04-25~2025-05-06  (4월)
# 248. 제28회 광주왕실도자페스티벌  2025-04-25~2025-05-06  (4월)
# 249. 제39회 이천도자기축제  2025-04-25~2025-05-06  (4월)
# 250. 제4회 계룡시 도시농업축제  2025-04-25~2025-04-26  (4월)
# 251. 제64회 아산 성웅 이순신축제  2025-04-25~2025-04-27  (4월)
# 252. 흑석산 소풍힐링축제  2025-04-25~2025-04-26  (4월)
# 253. 100+4 피아노섬 축제  2025-04-26~2025-04-27  (4월)
# 254. 2025 김제 모악뮤직페스티벌  2025-04-26~2025-04-27  (4월)
# 255. 2025년 대운산 철쭉제  2025-04-26~2025-04-26  (4월)
# 256. 목계별신제  2025-04-26~2025-04-27  (4월)
# 257. 산청황매산철쭉제  2025-04-26~2025-05-11  (4월)
# 258. 선사문화체험축제  2025-04-26~2025-04-27  (4월)
# 259. 신안 세계 김밥페스타  2025-04-26~2025-04-27  (4월)
# 260. 제29회 기장멸치축제  2025-04-26~2025-04-27  (4월)
# 261. 제29회 황매산철쭉제  2025-04-26~2025-05-11  (4월)
# 262. 제52회 윤봉길 평화축제  2025-04-26~2025-04-27  (4월)
# 263. 제6회 대한민국 함안 수박축제  2025-04-26~2025-04-28  (4월)
# 264. 황산 연호보리축제  2025-04-26~2025-04-26  (4월)
# 265. 서울페스타 2025  2025-04-30~2025-05-06  (4월)
# 266. 제95회 춘향제  2025-04-30~2025-05-06  (4월)
# 267. 서울페스타 2024  2024-05-01~2024-05-06  (5월)
# 268. 보성다향대축제  2024-05-02~2024-05-06  (5월)
# 269. 제18회 서울안전한마당  2024-05-02~2024-05-04  (5월)
# 270. 제19회 군산꽁당보리축제  2024-05-02~2024-05-04  (5월)
# 271. 제33회 안양예술제  2024-05-02~2024-05-02  (5월)
# 272. 한미친선 한마음 축제  2024-05-02~2024-05-02  (5월)
# 273. 2024 구리 유채꽃 축제  2024-05-03~2024-05-03  (5월)
# 274. 2024 예천활축제  2024-05-03~2024-05-06  (5월)
# 275. 2024 익산서동축제  2024-05-03~2024-05-06  (5월)
# 276. 2024 청춘양구 곰취축제  2024-05-03~2024-05-06  (5월)
# 277. 제11회 부안마실축제  2024-05-03~2024-05-06  (5월)
# 278. 제27회 광주왕실도자기축제  2024-05-03~2024-05-15  (5월)
# 279. 제2회 마이페스트  2024-05-03~2024-05-04  (5월)
# 280. 제31회 연천 구석기 축제  2024-05-03~2024-05-06  (5월)
# 281. 제36회 여주도자기축제  2024-05-03~2024-05-12  (5월)
# 282. 제39회 복사골예술제  2024-05-03~2024-05-05  (5월)
# 283. 조선통신사축제  2024-05-03~2024-05-05  (5월)
# 284. 차전장군노국공주축제  2024-05-03~2024-05-07  (5월)
# 285. 해남 공룡대축제  2024-05-03~2024-05-05  (5월)
# 286. 2024 가족의달 어린이축제  2024-05-04~2024-05-05  (5월)
# 287. 2024 보령.AMC 국제 모터페스티벌  2024-05-04~2024-05-06  (5월)
# 288. 의견문화제  2024-05-04~2024-05-06  (5월)
# 289. 의왕철도축제  2024-05-04~2024-05-05  (5월)
# 290. 제10회 황토갯벌축제  2024-05-04~2024-05-06  (5월)
# 291. 제13회 지평선 추억의 보리밭 축제  2024-05-04~2024-05-06  (5월)
# 292. 제20회 안산국제거리극축제  2024-05-04~2024-05-06  (5월)
# 293. 제21회 방선문축제  2024-05-04~2024-05-05  (5월)
# 294. 제24회 울산옹기축제  2024-05-04~2024-05-06  (5월)
# 295. 제2회 광산뮤직ON페스티벌  2024-05-04~2024-05-05  (5월)
# 296. 제58회 여수거북선축제  2024-05-04~2024-05-07  (5월)
# 297. 제5회 섬진강 슬로슬로 발효마을 축제  2024-05-04~2024-05-05  (5월)
# 298. 파주출판도시 어린이책잔치  2024-05-04~2024-05-06  (5월)
# 299. 제10회 대한민국 진도개페스티벌  2024-05-05~2024-05-06  (5월)
# 300. 제46회 대구약령시한방문화축제  2024-05-08~2024-05-12  (5월)
# ... (198개 더 있음)
